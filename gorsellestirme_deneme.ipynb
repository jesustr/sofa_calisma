# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None) 
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df = pd.read_csv('/Users/icy/Football_project/Footbal_project/csvler/last_df.csv', parse_dates=['date'])    
import numpy as np

# %%
df_all = pd.read_csv('/Users/icy/Desktop/sofa/sofa_all_works/csvler/last_df.csv', parse_dates=['date'])
df = df_all[['date','org_detay','home_team','away_team','corner_kick_total','corner_kicks_home','corner_kicks_away','corner_kicks_total_firsthalf','corner_kicks_home_firsthalf',
'corner_kicks_away_firsthalf','corner_kick_total_secondhalf','corner_kicks_home_secondhalf','corner_kicks_away_secondhalf','home_goal','away_goal','result','home_iy_goal','away_iy_goal','iy_result','referee','season','ulke','season_round','season_period']]
season = 7
df  = df[~(df.ulke == 'Europe')]
df_1 = df[(df.home_team.str.contains('Rize')) & (df.away_team.str.contains('Fener'))].sort_values(by= 'date', ascending= False)
df_2 = df[(df.home_team.str.contains('Fener')) & (df.away_team.str.contains('Rize'))].sort_values(by= 'date', ascending= False)

# %%
df_1.date = df_1.date.astype(str)
fig, ax = plt.subplots(2,2,figsize=(12,8),layout='constrained')  # layout='constrained' -> aralıkları otomatik ayarlar 
#bars = plt.bar(df_1['date'], df_1['corner_kick_total'])  #barh ile yan dönüyor
ax[0,0].bar(df_1['date'], df_1['corner_kick_total'],width=0.9,)  #barh ile yan dönüyor
ax[0,0].set_title('Total Corner')
#ax[1,1].bar_label(bars)
ax[1,1].set_title('Total Corner')
#ax[1,1].xaxis.set_visible(False)

fig.tight_layout() # grafikler arası boşluk düzenler

plt.show()
# Out:
# /var/folders/ll/svcq3_v57v9dwq0lwqhp4vpc0000gn/T/ipykernel_93427/3986063472.py:10: UserWarning: The figure layout has changed to tight
#   fig.tight_layout() # grafikler arası boşluk düzenler
