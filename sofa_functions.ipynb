# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None) 
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df = pd.read_csv('/Users/icy/sofascore/sofa_calisma/csvler/last_df.csv', parse_dates=['date'])    
import numpy as np

# %%
import pandas as pd 
from IPython.display import HTML
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None) 
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
    
def corner_(home,away,hafta= 5,period= None): 
    df_all = pd.read_csv('/Users/icy/sofascore/sofa_calisma/csvler/last_df.csv', parse_dates=['date'])
    df = df_all[['date','org_detay','home_team','away_team','corner_kick_total','corner_kicks_home','corner_kicks_away','corner_kick_total_firsthalf','corner_kicks_home_firsthalf',
    'corner_kicks_away_firsthalf','corner_kick_total_secondhalf','corner_kicks_home_secondhalf','corner_kicks_away_secondhalf','home_goal','away_goal','result','home_iy_goal','away_iy_goal','iy_result','referee','season','ulke','season_round','season_period']]
    season = 7
    df  = df[~(df.ulke == 'Europe')]
    df_1 = df[(df.home_team.str.contains(home)) & (df.away_team.str.contains(away))].sort_values(by= 'date', ascending= False)
    df_2 = df[(df.home_team.str.contains(away)) & (df.away_team.str.contains(home))].sort_values(by= 'date', ascending= False)
    df_iki_takim_corner = pd.concat([df_1,df_2])
    toplam_corner = list(df_iki_takim_corner['corner_kicks_home'] + df_iki_takim_corner['corner_kicks_away'])
    toplam_iy_corner = list(df_iki_takim_corner['corner_kicks_home_firsthalf'] + df_iki_takim_corner['corner_kicks_away_firsthalf'])
    toplam_ikinci_corner = list((df_iki_takim_corner['corner_kicks_home'] + df_iki_takim_corner['corner_kicks_away']) - (df_iki_takim_corner['corner_kicks_home_firsthalf'] + df_iki_takim_corner['corner_kicks_away_firsthalf']))
    df_home_team_corner = df[(df.home_team.str.contains(home))].sort_values(by= 'date', ascending=  False).head(hafta)
    home_toplam_corner = list(df_home_team_corner['corner_kicks_home'] + df_home_team_corner['corner_kicks_away'])
    home_toplam_iy_corner = list(df_home_team_corner['corner_kicks_home_firsthalf'] + df_home_team_corner['corner_kicks_away_firsthalf'])
    home_toplam_ikinci_corner = list((df_home_team_corner['corner_kicks_home'] + df_home_team_corner['corner_kicks_away']) - (df_home_team_corner['corner_kicks_home_firsthalf'] + df_home_team_corner['corner_kicks_away_firsthalf']))
    df_away_team_corner = df[(df.away_team.str.contains(away))].sort_values(by= 'date', ascending=  False).head(hafta)
    away_toplam_corner = list(df_away_team_corner['corner_kicks_home'] + df_away_team_corner['corner_kicks_away'])
    away_toplam_iy_corner = list(df_away_team_corner['corner_kicks_home_firsthalf'] + df_away_team_corner['corner_kicks_away_firsthalf'])
    away_toplam_ikinci_corner = list((df_away_team_corner['corner_kicks_home'] + df_away_team_corner['corner_kicks_away']) - (df_away_team_corner['corner_kicks_home_firsthalf'] + df_away_team_corner['corner_kicks_away_firsthalf']))
    # if not df_1.empty:
    #     ulke = df_1.ulke.iloc[0]
    #     df_hakem_corner_ort = df[(df.ulke == ulke) & (df.season > season - 1)].groupby('referee')[['corner_kick_total','corner_kicks_home','corner_kicks_away','corner_kick_total_firsthalf','corner_kicks_home_firsthalf','corner_kicks_away_firsthalf']].mean().to_html()        
    #     df_hakem_corner_ort = f'<div style="max-height: 300px; overflow-y: auto;">{df_hakem_corner_ort}</div>'
    # else:
    #     df_hakem_corner_ort = pd.DataFrame()
    

    display(f'{home} - {away} Arasindaki Maclar')
    display(f'Toplam Korner = {toplam_corner} - Ilk Yari Toplam Korner = {toplam_iy_corner} - Ikinci Yari Toplam Korner = {toplam_ikinci_corner}')
    display(df_iki_takim_corner)
    display(f'{home} Son Ev Maclari Istatistik')
    display(f'Toplam Korner = {home_toplam_corner} - Ilk Yari Toplam Korner = {home_toplam_iy_corner} - Ikinci Yari Toplam Korner = {home_toplam_ikinci_corner}')
    display(df_home_team_corner)
    display(f'{away} Son Dep Maclari Istatistik')
    display(f'Toplam Korner = {away_toplam_corner} - Ilk Yari Toplam Korner = {away_toplam_iy_corner} - Ikinci Yari Toplam Korner = {away_toplam_ikinci_corner}')
    display(df_away_team_corner)
    if period is not None :
        df_home_period_corner =  df[(df.home_team.str.contains(home)) & (df.season_period == period)].sort_values(by= 'date', ascending=  False)
        df_away_period_corner =  df[(df.away_team.str.contains(away)) & (df.season_period == period)].sort_values(by= 'date', ascending=  False)
        df_home_period_corner_html =  df[(df.home_team.str.contains(home)) & (df.season_period == period)].sort_values(by= 'date', ascending=  False).to_html()
        df_away_period_corner_html =  df[(df.away_team.str.contains(away)) & (df.season_period == period)].sort_values(by= 'date', ascending=  False).to_html()
        df_home_period_corner_html = f'<div style="max-height: 300px; overflow-y: auto;">{df_home_period_corner_html}</div>'
        df_away_period_corner_html = f'<div style="max-height: 300px; overflow-y: auto;">{df_away_period_corner_html}</div>'
        home_toplam_corner_period = list(df_home_period_corner['corner_kicks_home'] + df_home_period_corner['corner_kicks_away'])
        home_toplam_iy_corner_period = list(df_home_period_corner['corner_kicks_home_firsthalf'] + df_home_period_corner['corner_kicks_away_firsthalf'])
        home_toplam_ikinci_corner_period = list((df_home_period_corner['corner_kicks_home'] + df_home_period_corner['corner_kicks_away']) - (df_home_period_corner['corner_kicks_home_firsthalf'] + df_home_period_corner['corner_kicks_away_firsthalf']))
        away_toplam_corner_period = list(df_away_period_corner['corner_kicks_home'] + df_away_period_corner['corner_kicks_away'])
        away_toplam_iy_corner_period = list(df_away_period_corner['corner_kicks_home_firsthalf'] + df_away_period_corner['corner_kicks_away_firsthalf'])
        away_toplam_ikinci_corner_period = list((df_away_period_corner['corner_kicks_home'] + df_away_period_corner['corner_kicks_away']) - (df_away_period_corner['corner_kicks_home_firsthalf'] + df_away_period_corner['corner_kicks_away_firsthalf']))
        display(f'{home} {period}. Periyot Korner Istatistik (Ev Sahibi Oldugu Maclar)')
        display(f'Toplam Korner =             {home_toplam_corner_period}')
        display(f'Ilk Yari Toplam Korner =    {home_toplam_iy_corner_period}')
        display(f'Ikinci Yari Toplam Korner = {home_toplam_ikinci_corner_period}')
        display(HTML(df_home_period_corner_html))
        display(f'{away} {period}. Periyot Korner Istatistik (Konuk Takim Oldugu Maclar)')
        display(f'Toplam Korner =             {away_toplam_corner_period}')
        display(f'Ilk Yari Toplam Korner =    {away_toplam_iy_corner_period}')
        display(f'Ikinci Yari Toplam Korner = {away_toplam_ikinci_corner_period}')
        display(HTML(df_away_period_corner_html))

# %%
corner_('Lyon','Stras')
# Out:
# 'Lyon - Stras Arasindaki Maclar'
# 'Toplam Korner = [9, 16, 10, 8, 5, 9, 7, 7, 9, 8, 6, 4, 11, 3] - Ilk Yari Toplam Korner = [5, 9, 6, 3, 1, 5, 3, 3, 5, 4, 2, 2, 8, 3] - Ikinci Yari Toplam Korner = [4, 7, 4, 5, 4, 4, 4, 4, 4, 4, 4, 2, 3, 0]'
#             date org_detay   home_team   away_team  corner_kick_total  \
# 222   2024-05-19  Round 34        Lyon  Strasbourg                  9
# 4537  2023-01-14  Round 19        Lyon  Strasbourg                 16
# 8572  2021-09-12   Round 5        Lyon  Strasbourg                 10
# 10134 2021-02-06  Round 24        Lyon  Strasbourg                  8
# 12657 2020-02-16  Round 25        Lyon  Strasbourg                  5
# 17273 2018-08-24   Round 3        Lyon  Strasbourg                  9
# 20240 2017-08-05   Round 1        Lyon  Strasbourg                  7
# 2980  2023-08-13   Round 1  Strasbourg        Lyon                  7
# 3462  2023-04-28  Round 33  Strasbourg        Lyon                  9
# 6417  2022-04-10  Round 31  Strasbourg        Lyon                  8
# 11490 2020-10-18   Round 7  Strasbourg        Lyon                  6
# 13446 2019-11-30  Round 15  Strasbourg        Lyon                  4
# 15303 2019-03-09  Round 28  Strasbourg        Lyon                 11
# 17472 2018-05-12  Round 37  Strasbourg        Lyon                  3
#
#        corner_kicks_home  corner_kicks_away  corner_kick_total_firsthalf  \
# 222                    7                  2                            5
# 4537                  14                  2                            9
# 8572                   4                  6                            6
# 10134                  6                  2                            3
# 12657                  3                  2                            1
# 17273                  5                  4                            5
# 20240                  3                  4                            3
# 2980                   1                  6                            3
# 3462                   5                  4                            5
# 6417                   5                  3                            4
# 11490                  4                  2                            2
# 13446                  3                  1                            2
# 15303                  5                  6                            8
# 17472                  2                  1                            3
#
#        corner_kicks_home_firsthalf  corner_kicks_away_firsthalf  \
# 222                              4                            1
# 4537                             8                            1
# 8572                             2                            4
# 10134                            2                            1
# 12657                            1                            0
# 17273                            2                            3
# 20240                            3                            0
# 2980                             0                            3
# 3462                             2                            3
# 6417                             3                            1
# 11490                            2                            0
# 13446                            2                            0
# 15303                            3                            5
# 17472                            2                            1
#
#        corner_kick_total_secondhalf  corner_kicks_home_secondhalf  \
# 222                               4                             3
# 4537                              7                             6
# 8572                              4                             2
# 10134                             5                             4
# 12657                             4                             2
# 17273                             4                             3
# 20240                             4                             0
# 2980                              4                             1
# 3462                              4                             3
# 6417                              4                             2
# 11490                             4                             2
# 13446                             2                             1
# 15303                             3                             2
# 17472                             0                             0
#
#        corner_kicks_away_secondhalf  home_goal  away_goal  result  \
# 222                               1          2          1       1
# 4537                              1          1          2       2
# 8572                              2          3          1       1
# 10134                             1          3          0       1
# 12657                             2          1          1       0
# 17273                             1          2          0       1
# 20240                             4          4          0       1
# 2980                              3          2          1       1
# 3462                              1          1          2       2
# 6417                              2          1          1       0
# 11490                             2          2          3       2
# 13446                             1          1          2       2
# 15303                             1          2          2       0
# 17472                             0          3          2       1
#
#        home_iy_goal  away_iy_goal  iy_result             referee  season  \
# 222               1             0          1     Eric Wattellier       7
# 4537              1             2          2       Jeremy Stinat       6
# 8572              1             0          1        Ruddy Buquet       5
# 10134             2             0          1      Amaury Delerue       4
# 12657             1             1          0         Johan Hamel       3
# 17273             1             0          1      Amaury Delerue       2
# 20240             1             0          1        Ruddy Buquet       1
# 2980              0             0          0      Jérôme Brisard       7
# 3462              1             2          2        Ruddy Buquet       6
# 6417              1             0          1      Clement Turpin       5
# 11490             1             3          2        Ruddy Buquet       4
# 13446             1             1          0       Mikael Lesage       3
# 15303             0             1          2  Jerome Miguelgorry       2
# 17472             1             0          1      Clement Turpin       1
#
#          ulke  season_round  season_period
# 222    France            34              4
# 4537   France            19              3
# 8572   France             5              1
# 10134  France            24              3
# 12657  France            25              3
# 17273  France             3              1
# 20240  France             1              1
# 2980   France             1              1
# 3462   France            33              4
# 6417   France            31              4
# 11490  France             7              1
# 13446  France            15              2
# 15303  France            28              4
# 17472  France            37              4
# 'Lyon Son Ev Maclari Istatistik'
# 'Toplam Korner = [6, 9, 6, 17, 15] - Ilk Yari Toplam Korner = [3, 5, 1, 8, 7] - Ikinci Yari Toplam Korner = [3, 4, 5, 9, 8]'
#           date org_detay home_team   away_team  corner_kick_total  \
# 37  2024-08-24   Round 2      Lyon   AS Monaco                  6
# 222 2024-05-19  Round 34      Lyon  Strasbourg                  9
# 473 2024-04-28  Round 31      Lyon   AS Monaco                  6
# 607 2024-04-14  Round 29      Lyon       Brest                 17
# 785 2024-03-30  Round 27      Lyon       Reims                 15
#
#      corner_kicks_home  corner_kicks_away  corner_kick_total_firsthalf  \
# 37                   0                  6                            3
# 222                  7                  2                            5
# 473                  3                  3                            1
# 607                 10                  7                            8
# 785                  7                  8                            7
#
#      corner_kicks_home_firsthalf  corner_kicks_away_firsthalf  \
# 37                             0                            3
# 222                            4                            1
# 473                            1                            0
# 607                            4                            4
# 785                            5                            2
#
#      corner_kick_total_secondhalf  corner_kicks_home_secondhalf  \
# 37                              3                             0
# 222                             4                             3
# 473                             5                             2
# 607                             9                             6
# 785                             8                             2
#
#      corner_kicks_away_secondhalf  home_goal  away_goal  result  home_iy_goal  \
# 37                              3          0          2       2             0
# 222                             1          2          1       1             1
# 473                             3          3          2       1             2
# 607                             3          4          3       1             1
# 785                             6          1          1       0             0
#
#      away_iy_goal  iy_result             referee  season    ulke  \
# 37              0          2  Stephanie Frappart       8  France
# 222             0          1     Eric Wattellier       7  France
# 473             1          1     Bastien Dechepy       7  France
# 607             0          1     Mathieu Vernice       7  France
# 785             0          0      Thomas Leonard       7  France
#
#      season_round  season_period
# 37              2              1
# 222            34              4
# 473            31              4
# 607            29              4
# 785            27              3
# 'Stras Son Dep Maclari Istatistik'
# 'Toplam Korner = [10, 9, 5, 8, 7] - Ilk Yari Toplam Korner = [7, 5, 3, 4, 1] - Ikinci Yari Toplam Korner = [3, 4, 2, 4, 6]'
#           date org_detay    home_team   away_team  corner_kick_total  \
# 78  2024-08-18   Round 1  Montpellier  Strasbourg                 10
# 222 2024-05-19  Round 34         Lyon  Strasbourg                  9
# 413 2024-05-04  Round 32     Le Havre  Strasbourg                  5
# 537 2024-04-21  Round 30        Lille  Strasbourg                  8
# 675 2024-04-07  Round 28     Toulouse  Strasbourg                  7
#
#      corner_kicks_home  corner_kicks_away  corner_kick_total_firsthalf  \
# 78                   6                  4                            7
# 222                  7                  2                            5
# 413                  3                  2                            3
# 537                  4                  4                            4
# 675                  4                  3                            1
#
#      corner_kicks_home_firsthalf  corner_kicks_away_firsthalf  \
# 78                             5                            2
# 222                            4                            1
# 413                            2                            1
# 537                            3                            1
# 675                            1                            0
#
#      corner_kick_total_secondhalf  corner_kicks_home_secondhalf  \
# 78                              3                             1
# 222                             4                             3
# 413                             2                             1
# 537                             4                             1
# 675                             6                             3
#
#      corner_kicks_away_secondhalf  home_goal  away_goal  result  home_iy_goal  \
# 78                              2          1          1       0             0
# 222                             1          2          1       1             1
# 413                             1          3          1       1             1
# 537                             3          1          0       1             1
# 675                             3          0          0       0             0
#
#      away_iy_goal  iy_result          referee  season    ulke  season_round  \
# 78              0          0  Mathieu Vernice       8  France             1
# 222             0          1  Eric Wattellier       7  France            34
# 413             0          1   Jérôme Brisard       7  France            32
# 537             0          1    Benoît Millot       7  France            30
# 675             0          0     Ruddy Buquet       7  France            28
#
#      season_period
# 78               1
# 222              4
# 413              4
# 537              4
# 675              4

# %%
df[df.home_team.str.contains('Pauli')][:20]
# Out:
#     Unnamed: 0       date  hour     ulke organizasyon org_detay  home_team  \
# 17          17 2024-08-25    18  Germany   Bundesliga   Round 1  St. Pauli
#
#     home_goal  away_goal   away_team  result  home_iy_goal  away_iy_goal  \
# 17          0          2  Heidenheim       2             0             0
#
#     iy_result  corner_kicks_home  corner_kicks_home_firsthalf  \
# 17          2                  4                            0
#
#     corner_kicks_away  corner_kicks_away_firsthalf  total_shots_home  \
# 17                  2                            1                11
#
#     total_shots_home_firsthalf  shots_on_target_home  \
# 17                           4                     3
#
#     shots_on_target_home_firsthalf  total_shots_away  \
# 17                               1                 5
#
#     total_shots_away_firsthalf  shots_on_target_away  \
# 17                           1                     3
#
#     shots_on_target_away_firsthalf  fouls_home  fouls_away  yellow_cards_home  \
# 17                               0           9          15                  2
#
#     yellow_cards_home_firsthalf  yellow_cards_away  \
# 17                            2                  3
#
#     yellow_cards_away_firsthalf  red_cards_home  red_cards_home_firsthalf  \
# 17                            1               0                         0
#
#     red_cards_away  red_cards_away_firsthalf         referee  \
# 17               0                         0  Sven Jablonski
#
#     shots_inside_box_home  shots_inside_box_away  shots_outside_box_home  \
# 17                      6                      3                       5
#
#     shots_outside_box_away  free_kicks_home  free_kicks_away  \
# 17                       2               15                9
#
#     ball_possession_home  ball_possession_away  passes_home  passes_away  \
# 17                    61                    39          545          350
#
#     ball_possession_home_firsthalf  ball_possession_away_firsthalf  \
# 17                              56                              44
#
#     passes_home_firsthalf  passes_away_firsthalf  free_kicks_home_firsthalf  \
# 17                    298                    229                          6
#
#     free_kicks_away_firsthalf  shots_inside_box_home_firsthalf  \
# 17                          5                                2
#
#     shots_inside_box_away_firsthalf  shots_outside_box_home_firsthalf  \
# 17                                0                                 2
#
#     shots_outside_box_away_firsthalf  total_shots_home_secondhalf  \
# 17                                 1                            7
#
#     total_shots_away_secondhalf  shots_on_target_home_secondhalf  \
# 17                            4                                2
#
#     shots_on_target_away_secondhalf  shots_inside_box_home_secondhalf  \
# 17                                3                                 4
#
#     shots_inside_box_away_secondhalf  shots_outside_box_home_secondhalf  \
# 17                                 3                                  3
#
#     corner_kicks_home_secondhalf  corner_kicks_away_secondhalf  \
# 17                             4                             1
#
#     passes_home_secondhalf  passes_away_secondhalf  \
# 17                     247                     121
#
#     free_kicks_home_secondhalf  yellow_cards_home_secondhalf  \
# 17                           9                             0
#
#     yellow_cards_away_secondhalf  red_cards_home_secondhalf  \
# 17                             2                          0
#
#     red_cards_away_secondhalf  free_kicks_away_secondhalf  \
# 17                          0                           4
#
#                                                                                   match_link  \
# 17  https://www.sofascore.com/football/match/1-fc-heidenheim-fc-st-pauli/BabsKrc#id:12499462
#
#     season  season_round  season_period  kg_var  corner_kick_total  \
# 17       8             1              1       0                  6
#
#     corner_kick_total_firsthalf  corner_kick_total_secondhalf  \
# 17                            1                             5
#
#     total_shots_firsthalf  total_shots  total_shots_secondhalf  \
# 17                      5           16                      11
#
#     yellow_cards_total  red_cards_total  yellow_cards_firsthalf_total  \
# 17                   5                0                             3
#
#     yellow_cards_secondhalf_total  red_cards_firsthalf_total  \
# 17                              2                          0
#
#     red_cards_secondhalf_total  1.5o  2.5o  point_away  place_away  \
# 17                           0     1     0           3           2
#
#     point_home  place_home  league_match  match_round  shots_on_target_total  \
# 17           0          18             1            1                      6
#
#     shots_on_target_total_firsthalf  shots_on_target_total_secondhalf
# 17                                1                                 5

# %%
df.columns[df.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
df[df.home_team == 'PSG']
# Out:
#        Unnamed: 0       date  hour    ulke  \
# 65             65 2024-08-23    21  France
# 311           311 2024-05-12    22  France
# 361           361 2024-05-07    22  Europe
# 485           485 2024-04-27    22  France
# 529           529 2024-04-21    22  France
# ...           ...        ...   ...     ...
# 19747       19747 2017-09-27    21  Europe
# 19874       19874 2017-09-17    22  France
# 20099       20099 2017-08-25    21  France
# 20135       20135 2017-08-20    22  France
# 20244       20244 2017-08-05    18  France
#
#                                 organizasyon  org_detay home_team  home_goal  \
# 65                                   Ligue 1    Round 2       PSG          6
# 311                                  Ligue 1   Round 33       PSG          1
# 361    UEFA Champions League, Knockout stage  Semifinal       PSG          0
# 485                                  Ligue 1   Round 31       PSG          3
# 529                                  Ligue 1   Round 30       PSG          4
# ...                                      ...        ...       ...        ...
# 19747         UEFA Champions League, Group B    Round 2       PSG          3
# 19874                                Ligue 1    Round 6       PSG          2
# 20099                                Ligue 1    Round 4       PSG          3
# 20135                                Ligue 1    Round 3       PSG          6
# 20244                                Ligue 1    Round 1       PSG          2
#
#        away_goal      away_team  result  home_iy_goal  away_iy_goal  \
# 65             0    Montpellier       1             2             0
# 311            3       Toulouse       2             1             1
# 361            1       Dortmund       2             0             0
# 485            3       Le Havre       0             1             2
# 529            1           Lyon       1             4             1
# ...          ...            ...     ...           ...           ...
# 19747          0         Bayern       1             2             0
# 19874          0           Lyon       1             0             0
# 20099          0  Saint-Étienne       1             1             0
# 20135          2       Toulouse       1             2             1
# 20244          0         Amiens       1             1             0
#
#        iy_result  corner_kicks_home  corner_kicks_home_firsthalf  \
# 65             1                 10                            5
# 311            0                  4                            0
# 361            0                 12                            3
# 485            2                 11                            7
# 529            1                  4                            2
# ...          ...                ...                          ...
# 19747          1                  1                            1
# 19874          0                  9                            6
# 20099          1                  8                            3
# 20135          1                  7                            3
# 20244          1                  8                            5
#
#        corner_kicks_away  corner_kicks_away_firsthalf  total_shots_home  \
# 65                     2                            1                27
# 311                    6                            5                15
# 361                    4                            1                30
# 485                    2                            2                17
# 529                   10                            5                14
# ...                  ...                          ...               ...
# 19747                 18                           10                12
# 19874                  4                            1                14
# 20099                  3                            3                14
# 20135                  1                            0                23
# 20244                  3                            1                16
#
#        total_shots_home_firsthalf  shots_on_target_home  \
# 65                             12                    11
# 311                             5                     3
# 361                             8                     5
# 485                             7                     4
# 529                             9                     6
# ...                           ...                   ...
# 19747                           5                     5
# 19874                           4                     5
# 20099                           1                     4
# 20135                          15                    14
# 20244                          12                     5
#
#        shots_on_target_home_firsthalf  total_shots_away  \
# 65                                  3                 8
# 311                                 1                18
# 361                                 3                 7
# 485                                 1                 6
# 529                                 4                16
# ...                               ...               ...
# 19747                               3                16
# 19874                               1                13
# 20099                               1                12
# 20135                               8                 7
# 20244                               2                 7
#
#        total_shots_away_firsthalf  shots_on_target_away  \
# 65                              3                     3
# 311                            11                     5
# 361                             4                     3
# 485                             5                     4
# 529                            11                     6
# ...                           ...                   ...
# 19747                           9                     7
# 19874                           6                     5
# 20099                           8                     2
# 20135                           2                     1
# 20244                           2                     1
#
#        shots_on_target_away_firsthalf  fouls_home  fouls_away  \
# 65                                  1          11          17
# 311                                 3          12           8
# 361                                 2           8           6
# 485                                 3          10           8
# 529                                 3           9          10
# ...                               ...         ...         ...
# 19747                               3          10          18
# 19874                               1          11          15
# 20099                               1          20          12
# 20135                               1           8          19
# 20244                               0           9          12
#
#        yellow_cards_home  yellow_cards_home_firsthalf  yellow_cards_away  \
# 65                     1                            0                  4
# 311                    0                            0                  0
# 361                    2                            0                  2
# 485                    2                            0                  1
# 529                    0                            0                  0
# ...                  ...                          ...                ...
# 19747                  1                            0                  4
# 19874                  3                            1                  2
# 20099                  2                            2                  3
# 20135                  2                            0                  4
# 20244                  0                            0                  1
#
#        yellow_cards_away_firsthalf  red_cards_home  red_cards_home_firsthalf  \
# 65                               2               0                         0
# 311                              0               0                         0
# 361                              0               0                         0
# 485                              0               0                         0
# 529                              0               0                         0
# ...                            ...             ...                       ...
# 19747                            2               0                         0
# 19874                            0               0                         0
# 20099                            1               0                         0
# 20135                            0               1                         0
# 20244                            0               0                         0
#
#        red_cards_away  red_cards_away_firsthalf              referee  \
# 65                  0                         0      Marc Bollengier
# 311                 0                         0        Florent Batta
# 361                 0                         0       Daniele Orsato
# 485                 0                         0        Willy Delajod
# 529                 0                         0    François Letexier
# ...               ...                       ...                  ...
# 19747               0                         0  Antonio Mateu Lahoz
# 19874               0                         0         Ruddy Buquet
# 20099               0                         0       Clement Turpin
# 20135               0                         0       Amaury Delerue
# 20244               0                         0        Mikael Lesage
#
#        shots_inside_box_home  shots_inside_box_away  shots_outside_box_home  \
# 65                        17                      6                      10
# 311                       11                     12                       4
# 361                       18                      7                      12
# 485                        7                      5                      10
# 529                       12                      8                       2
# ...                      ...                    ...                     ...
# 19747                      6                      9                       6
# 19874                     11                      8                       3
# 20099                      7                      4                       7
# 20135                     15                      4                       8
# 20244                     10                      3                       6
#
#        shots_outside_box_away  free_kicks_home  free_kicks_away  \
# 65                          2               14               10
# 311                         6                8               10
# 361                         0                6                8
# 485                         1                8                8
# 529                         8                8                9
# ...                       ...              ...              ...
# 19747                       7               15                9
# 19874                       5               15               11
# 20099                       8               12               20
# 20135                       3               17                8
# 20244                       4               11                8
#
#        ball_possession_home  ball_possession_away  passes_home  passes_away  \
# 65                       69                    31          744          338
# 311                      64                    36          653          354
# 361                      70                    30          659          295
# 485                      77                    23          742          221
# 529                      63                    37          741          425
# ...                     ...                   ...          ...          ...
# 19747                    38                    62          370          572
# 19874                    70                    30          686          293
# 20099                    61                    39          601          378
# 20135                    73                    27          639          224
# 20244                    68                    32          730          338
#
#        ball_possession_home_firsthalf  ball_possession_away_firsthalf  \
# 65                                 69                              31
# 311                                58                              42
# 361                                61                              39
# 485                                74                              26
# 529                                59                              41
# ...                               ...                             ...
# 19747                              34                              66
# 19874                              69                              31
# 20099                              62                              38
# 20135                              72                              28
# 20244                              71                              29
#
#        passes_home_firsthalf  passes_away_firsthalf  \
# 65                       364                    163
# 311                      292                    199
# 361                      314                    201
# 485                      357                    127
# 529                      316                    213
# ...                      ...                    ...
# 19747                    176                    327
# 19874                    357                    164
# 20099                    305                    179
# 20135                    328                    125
# 20244                    384                    151
#
#        free_kicks_home_firsthalf  free_kicks_away_firsthalf  \
# 65                             9                          2
# 311                            3                          6
# 361                            1                          5
# 485                            3                          4
# 529                            3                          5
# ...                          ...                        ...
# 19747                          6                          3
# 19874                          8                          6
# 20099                          6                          8
# 20135                          5                          5
# 20244                          1                          5
#
#        shots_inside_box_home_firsthalf  shots_inside_box_away_firsthalf  \
# 65                                   7                                2
# 311                                  4                                7
# 361                                  4                                4
# 485                                  2                                4
# 529                                  9                                4
# ...                                ...                              ...
# 19747                                3                                5
# 19874                                3                                2
# 20099                                1                                3
# 20135                               10                                1
# 20244                                7                                1
#
#        shots_outside_box_home_firsthalf  shots_outside_box_away_firsthalf  \
# 65                                    5                                 1
# 311                                   1                                 4
# 361                                   4                                 0
# 485                                   5                                 1
# 529                                   0                                 7
# ...                                 ...                               ...
# 19747                                 2                                 4
# 19874                                 1                                 4
# 20099                                 0                                 5
# 20135                                 5                                 1
# 20244                                 5                                 1
#
#        total_shots_home_secondhalf  total_shots_away_secondhalf  \
# 65                              15                            5
# 311                             10                            7
# 361                             22                            3
# 485                             10                            1
# 529                              5                            5
# ...                            ...                          ...
# 19747                            7                            7
# 19874                           10                            7
# 20099                           13                            4
# 20135                            8                            5
# 20244                            4                            5
#
#        shots_on_target_home_secondhalf  shots_on_target_away_secondhalf  \
# 65                                   8                                2
# 311                                  2                                2
# 361                                  2                                1
# 485                                  3                                1
# 529                                  2                                3
# ...                                ...                              ...
# 19747                                2                                4
# 19874                                4                                4
# 20099                                3                                1
# 20135                                6                                0
# 20244                                3                                1
#
#        shots_inside_box_home_secondhalf  shots_inside_box_away_secondhalf  \
# 65                                   10                                 4
# 311                                   7                                 5
# 361                                  14                                 3
# 485                                   5                                 1
# 529                                   3                                 4
# ...                                 ...                               ...
# 19747                                 3                                 4
# 19874                                 8                                 6
# 20099                                 6                                 1
# 20135                                 5                                 3
# 20244                                 3                                 2
#
#        shots_outside_box_home_secondhalf  corner_kicks_home_secondhalf  \
# 65                                     5                             5
# 311                                    3                             4
# 361                                    8                             9
# 485                                    5                             4
# 529                                    2                             2
# ...                                  ...                           ...
# 19747                                  4                             0
# 19874                                  2                             3
# 20099                                  7                             5
# 20135                                  3                             4
# 20244                                  1                             3
#
#        corner_kicks_away_secondhalf  passes_home_secondhalf  \
# 65                                1                     380
# 311                               1                     361
# 361                               3                     345
# 485                               0                     385
# 529                               5                     425
# ...                             ...                     ...
# 19747                             8                     194
# 19874                             3                     329
# 20099                             0                     296
# 20135                             1                     311
# 20244                             2                     346
#
#        passes_away_secondhalf  free_kicks_home_secondhalf  \
# 65                        175                           5
# 311                       155                           5
# 361                        94                           5
# 485                        94                           5
# 529                       212                           5
# ...                       ...                         ...
# 19747                     245                           9
# 19874                     129                           7
# 20099                     199                           6
# 20135                      99                          12
# 20244                     187                          10
#
#        yellow_cards_home_secondhalf  yellow_cards_away_secondhalf  \
# 65                                1                             2
# 311                               0                             0
# 361                               2                             2
# 485                               2                             1
# 529                               0                             0
# ...                             ...                           ...
# 19747                             1                             2
# 19874                             2                             2
# 20099                             0                             2
# 20135                             2                             4
# 20244                             0                             1
#
#        red_cards_home_secondhalf  red_cards_away_secondhalf  \
# 65                             0                          0
# 311                            0                          0
# 361                            0                          0
# 485                            0                          0
# 529                            0                          0
# ...                          ...                        ...
# 19747                          0                          0
# 19874                          0                          0
# 20099                          0                          0
# 20135                          1                          0
# 20244                          0                          0
#
#        free_kicks_away_secondhalf  \
# 65                              8
# 311                             4
# 361                             3
# 485                             4
# 529                             4
# ...                           ...
# 19747                           6
# 19874                           5
# 20099                          12
# 20135                           3
# 20244                           3
#
#                                                                                               match_link  \
# 65             https://www.sofascore.com/football/match/paris-saint-germain-montpellier/RHUH#id:12450874
# 311               https://www.sofascore.com/football/match/toulouse-paris-saint-germain/YMTc#id:11391267
# 361    https://www.sofascore.com/football/match/borussia-dortmund-paris-saint-germain/UHsydb#id:12173507
# 485              https://www.sofascore.com/football/match/le-havre-paris-saint-germain/UHsmI#id:11391300
# 529    https://www.sofascore.com/football/match/olympique-lyonnais-paris-saint-germain/UHsZH#id:11391289
# ...                                                                                                  ...
# 19747   https://www.sofascore.com/football/match/fc-bayern-munchen-paris-saint-germain/UHsxdb#id:7551797
# 19874   https://www.sofascore.com/football/match/olympique-lyonnais-paris-saint-germain/UHsZH#id:7438744
# 20099         https://www.sofascore.com/football/match/saint-etienne-paris-saint-germain/UHDI#id:7438384
# 20135              https://www.sofascore.com/football/match/toulouse-paris-saint-germain/YMTc#id:7438385
# 20244            https://www.sofascore.com/football/match/amiens-sc-paris-saint-germain/UHsBI#id:7438244
#
#        season  season_round  season_period  kg_var  corner_kick_total  \
# 65          8             2              1       0                 12
# 311         7            33              4       1                 10
# 361         7             0              0       0                 16
# 485         7            31              4       1                 13
# 529         7            30              4       1                 14
# ...       ...           ...            ...     ...                ...
# 19747       1             0              0       0                 19
# 19874       1             6              1       0                 13
# 20099       1             4              1       0                 11
# 20135       1             3              1       1                  8
# 20244       1             1              1       0                 11
#
#        corner_kick_total_firsthalf  corner_kick_total_secondhalf  \
# 65                               6                             6
# 311                              5                             5
# 361                              4                            12
# 485                              9                             4
# 529                              7                             7
# ...                            ...                           ...
# 19747                           11                             8
# 19874                            7                             6
# 20099                            6                             5
# 20135                            3                             5
# 20244                            6                             5
#
#        total_shots_firsthalf  total_shots  total_shots_secondhalf  \
# 65                        15           35                      20
# 311                       16           33                      17
# 361                       12           37                      25
# 485                       12           23                      11
# 529                       20           30                      10
# ...                      ...          ...                     ...
# 19747                     14           28                      14
# 19874                     10           27                      17
# 20099                      9           26                      17
# 20135                     17           30                      13
# 20244                     14           23                       9
#
#        yellow_cards_total  red_cards_total  yellow_cards_firsthalf_total  \
# 65                      5                0                             2
# 311                     0                0                             0
# 361                     4                0                             0
# 485                     3                0                             0
# 529                     0                0                             0
# ...                   ...              ...                           ...
# 19747                   5                0                             2
# 19874                   5                0                             1
# 20099                   5                0                             3
# 20135                   6                1                             0
# 20244                   1                0                             0
#
#        yellow_cards_secondhalf_total  red_cards_firsthalf_total  \
# 65                                 3                          0
# 311                                0                          0
# 361                                4                          0
# 485                                3                          0
# 529                                0                          0
# ...                              ...                        ...
# 19747                              3                          0
# 19874                              4                          0
# 20099                              2                          0
# 20135                              6                          0
# 20244                              1                          0
#
#        red_cards_secondhalf_total  1.5o  2.5o  point_away  place_away  \
# 65                              0     1     1           1          14
# 311                             0     1     1          43          11
# 361                             0     0     0           0           0
# 485                             0     1     1          32          15
# 529                             0     1     1          53           6
# ...                           ...   ...   ...         ...         ...
# 19747                           0     1     1           0           0
# 19874                           0     1     0          78           3
# 20099                           0     1     1          55           7
# 20135                           1     1     1          37          18
# 20244                           0     1     0          45          13
#
#        point_home  place_home  league_match  match_round  \
# 65              6           1             1            2
# 311            76           1             1           33
# 361             0           0             0            0
# 485            76           1             1           31
# 529            76           1             1           30
# ...           ...         ...           ...          ...
# 19747           0           0             0            0
# 19874          93           1             1            6
# 20099          93           1             1            4
# 20135          93           1             1            3
# 20244          93           1             1            1
#
#        shots_on_target_total  shots_on_target_total_firsthalf  \
# 65                        14                                4
# 311                        8                                4
# 361                        8                                5
# 485                        8                                4
# 529                       12                                7
# ...                      ...                              ...
# 19747                     12                                6
# 19874                     10                                2
# 20099                      6                                2
# 20135                     15                                9
# 20244                      6                                2
#
#        shots_on_target_total_secondhalf
# 65                                   10
# 311                                   4
# 361                                   3
# 485                                   4
# 529                                   5
# ...                                 ...
# 19747                                 6
# 19874                                 8
# 20099                                 4
# 20135                                 6
# 20244                                 4
#
# [160 rows x 102 columns]

# %%
d
