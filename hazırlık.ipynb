# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option('display.max_colwidth', None) 
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df = pd.read_csv('/Users/icy/sofascore/sofa_calisma/csvler/last_df.csv', parse_dates=['date'])

# %%
df.head()
# Out:
#         date  hour     ulke organizasyon org_detay   home_team  home_goal  \
# 0 2024-09-01    19  Türkiye    Super Lig   Round 4    Eyüpspor          0
# 1 2024-09-01    21  Türkiye    Super Lig   Round 4    Beşiktaş          2
# 2 2024-09-01    19  Türkiye    Super Lig   Round 4  Başakşehir          5
# 3 2024-09-01    21  Türkiye    Super Lig   Round 4   Hatayspor          0
# 4 2024-09-01    20    Spain       LaLiga   Round 4     Sevilla          0
#
#    away_goal    away_team  result  home_iy_goal  away_iy_goal  iy_result  \
# 0          0  Trabzonspor       0             0             0          0
# 1          0    Sivasspor       1             1             0          1
# 2          2  Antalyaspor       1             1             2          0
# 3          3   Samsunspor       2             0             1          2
# 4          2       Girona       2             0             1          2
#
#    corner_kicks_home  corner_kicks_home_firsthalf  corner_kicks_away  \
# ...

# %%
df.columns.tolist()
# Out:
# ['date',
#  'hour',
#  'ulke',
#  'organizasyon',
#  'org_detay',
#  'home_team',
#  'home_goal',
#  'away_goal',
#  'away_team',
#  'result',
#  'home_iy_goal',
#  'away_iy_goal',
#  'iy_result',
#  'corner_kicks_home',
#  'corner_kicks_home_firsthalf',
#  'corner_kicks_away',
#  'corner_kicks_away_firsthalf',
#  'total_shots_home',
#  'total_shots_home_firsthalf',
#  'shots_on_target_home',
#  'shots_on_target_home_firsthalf',
#  'total_shots_away',
#  'total_shots_away_firsthalf',
#  'shots_on_target_away',
#  'shots_on_target_away_firsthalf',
#  'fouls_home',
#  'fouls_away',
#  'yellow_cards_home',
#  'yellow_cards_home_firsthalf',
#  'yellow_cards_away',
#  'yellow_cards_away_firsthalf',
#  'red_cards_home',
#  'red_cards_home_firsthalf',
#  'red_cards_away',
#  'red_cards_away_firsthalf',
#  'referee',
#  'shots_inside_box_home',
#  'shots_inside_box_away',
#  'shots_outside_box_home',
#  'shots_outside_box_away',
#  'free_kicks_home',
#  'free_kicks_away',
# ...

# %%
df[['date','ulke','org_detay','home_team','home_goal','away_goal','away_team','result','home_iy_goal','away_iy_goal','iy_result','home_sh_goal','away_sh_goal','sh_result',
'1.5o','2.5o','point_away','place_away','point_home','place_home',]]
# Out:
#             date     ulke org_detay      home_team  home_goal  away_goal  \
# 0     2024-09-01  Türkiye   Round 4       Eyüpspor          0          0
# 1     2024-09-01  Türkiye   Round 4       Beşiktaş          2          0
# 2     2024-09-01  Türkiye   Round 4     Başakşehir          5          2
# 3     2024-09-01  Türkiye   Round 4      Hatayspor          0          3
# 4     2024-09-01    Spain   Round 4        Sevilla          0          2
# ...          ...      ...       ...            ...        ...        ...
# 20326 2017-08-05   France   Round 1  Saint-Étienne          1          0
# 20327 2017-08-05   France   Round 1    Montpellier          1          0
# 20328 2017-08-05   France   Round 1           Lyon          4          0
# 20329 2017-08-05   France   Round 1           Metz          1          3
# 20330 2017-08-04   France   Round 1      AS Monaco          3          2
#
#          away_team  result  home_iy_goal  away_iy_goal  iy_result  \
# ...
