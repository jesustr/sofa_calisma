# %%
from my_functions import corner
# corner(home_team= , away_team= , period=)
# corner(home_team= , away_team= , period= , max_home_sira= , min_home_sira= , max_away_sira= , min_away_sira=)

# %%
corner(home_team= 'Athletic' , away_team= 'Valencia', period= 1 , max_home_sira=9 , min_home_sira=3 , max_away_sira=12 , min_away_sira=6 )
