# %%
import pandas as pd 
from my_functions import corner,shoot_on_target
df = pd.read_csv('/Users/icy/sofascore/sofa_calisma/csvler/last_df.csv', parse_dates=['date'])
import importlib
import my_functions, new
importlib.reload(my_functions) #-> function u her defasında yeniden yükler yapılan degisiklikler hemen tesir eder.
 #-> function u her defasında yeniden yükler yapılan degisiklikler hemen tesir eder.
# corner(home_team= , away_team= , period=)
# corner(home_team= , away_team= , period= , max_home_sira= , min_home_sira= , max_away_sira= , min_away_sira=)
# Out:
# <module 'my_functions' from '/Users/icy/sofascore/sofa_calisma/my_functions.py'>

# %%
corner(home_team= home_team , away_team= away_team, period= 1 , max_home_sira=9 , min_home_sira=3 , max_away_sira=13 , min_away_sira=6 )

# %%
shoot_on_target(home_team= home_team , away_team= away_team, period= 1 , max_home_sira=9 , min_home_sira=3 , max_away_sira=13 , min_away_sira=6 )

# %%
# goal ve faul uzerine dusun **
df[(df.home_team.str.contains(home_team)) & (df.away_team.str.contains(away_team))][['date','org_detay','ulke','home_team','home_goal','away_goal','away_team','result','home_iy_goal','away_iy_goal','iy_result',
'shots_on_target_total',
'shots_on_target_home','shots_on_target_home_firsthalf','shots_on_target_home_secondhalf','shots_on_target_away','shots_on_target_away_firsthalf','shots_on_target_away_secondhalf','total_shots_away',
'total_shots_away_firsthalf','total_shots_away_secondhalf','total_shots_home','total_shots_home_firsthalf','total_shots_home_secondhalf','fouls_home', 'fouls_away','season_period','place_away','place_home',
'match_round']]
# Out:
#             date org_detay   ulke    home_team  home_goal  away_goal  \
# 4830  2022-11-06  Round 13  Spain  Atl. Madrid          1          1
# 6334  2022-04-17  Round 32  Spain  Atl. Madrid          2          1
# 13550 2019-11-10  Round 13  Spain  Atl. Madrid          3          1
# 16064 2018-12-22  Round 17  Spain  Atl. Madrid          1          0
# 17512 2018-05-06  Round 36  Spain  Atl. Madrid          0          2
#
#       away_team  result  home_iy_goal  away_iy_goal  iy_result  \
# 4830   Espanyol       0             0             0          0
# 6334   Espanyol       1             0             0          0
# 13550  Espanyol       1             1             1          0
# 16064  Espanyol       1             0             0          0
# 17512  Espanyol       2             0             0          0
#
#        shots_on_target_total  shots_on_target_home  \
# 4830                       9                     7
# 6334                       8                     3
# ...

# %%
df[(df.home_team.str.contains(away_team)) & (df.away_team.str.contains(home_team))][['date','org_detay','ulke','home_team','home_goal','away_goal','away_team','result','home_iy_goal','away_iy_goal','iy_result',
'shots_on_target_home','shots_on_target_home_firsthalf','shots_on_target_home_secondhalf','shots_on_target_away','shots_on_target_away_firsthalf','shots_on_target_away_secondhalf','total_shots_away',
'total_shots_away_firsthalf','total_shots_away_secondhalf','total_shots_home','total_shots_home_firsthalf','total_shots_home_secondhalf','fouls_home', 'fouls_away','season_period','place_away','place_home',
'match_round',
'shots_on_target_total_firsthalf',
'shots_on_target_total_secondhalf']]
# Out:
#             date org_detay   ulke home_team  home_goal  away_goal  \
# 3152  2023-05-24  Round 36  Spain  Espanyol          3          3
# 8576  2021-09-12   Round 4  Spain  Espanyol          1          2
# 12522 2020-03-01  Round 26  Spain  Espanyol          1          1
# 14744 2019-05-04  Round 36  Spain  Espanyol          3          0
# 18861 2017-12-22  Round 17  Spain  Espanyol          1          0
#
#          away_team  result  home_iy_goal  away_iy_goal  iy_result  \
# 3152   Atl. Madrid       0             0             2          2
# 8576   Atl. Madrid       2             1             0          1
# 12522  Atl. Madrid       0             1             0          1
# 14744  Atl. Madrid       1             1             0          1
# 18861  Atl. Madrid       1             0             0          0
#
#        shots_on_target_home  shots_on_target_home_firsthalf  \
# 3152                     13                               6
# ...
